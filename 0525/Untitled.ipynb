# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

# %%
x = np.linspace(-3, 3, 600)

# %%
y = -np.log(1/(1+np.power(np.e, -x)))

# %%
plt.figure(figsize=(8,4))

# %%
plt.plot(x,y)

# %%
z=-np.log(1-(1/(1+np.power(e,-x))))

# %%
plot(x,z)
